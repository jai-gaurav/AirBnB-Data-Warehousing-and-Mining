# %% [markdown]
# # Importing necessary modules

# %%
import pandas as pd

# %% [markdown]
# # Reading the dataset

# %%
df = pd.read_csv("AB_NYC_2019.csv")

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2             NaN                NaN                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19               0.10                               1
# ...           ...                ...                             ...
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %% [markdown]
# # Location - wise filtering

# %%
def location_filter(loc_name):
    return df.loc[df['neighbourhood_group'].str.contains(loc_name, case=False, regex=False)]

# %%
loc_df = location_filter(input("Enter required location: "))
loc_df
# Out:
# Enter required location: Brooklyn
#              id                                             name    host_id  \
# 0          2539               Clean & quiet apt home by the park       2787
# 3          3831                  Cozy Entire Floor of Brownstone       4869
# 6          5121                                  BlissArtsSpace!       7356
# 12         5803   Lovely Room 1, Garden, Best Area, Legal rental       9744
# 15         6848                 Only 2 stops to Manhattan studio      15991
# ...         ...                                              ...        ...
# 48882  36482231                        Bushwick _ Myrtle-Wyckoff   66058896
# 48884  36482783      Brooklyn Oasis in the heart of Williamsburg  274307600
# 48887  36483152  Garden Jewel Apartment in Williamsburg New York  208514239
# 48890  36484665  Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057    Affordable room in Bushwick/East Williamsburg    6570630
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 6              Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 12            Laurie            Brooklyn         South Slope  40.66829
# 15     Allen & Irina            Brooklyn        Williamsburg  40.70837
# ...              ...                 ...                 ...       ...
# 48882          Luisa            Brooklyn            Bushwick  40.69652
# 48884       Jonathan            Brooklyn        Williamsburg  40.71790
# 48887          Melki            Brooklyn        Williamsburg  40.71232
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 3      -73.95976  Entire home/apt     89               1                270
# 6      -73.95596     Private room     60              45                 49
# 12     -73.98779     Private room     89               4                167
# 15     -73.95352  Entire home/apt    140               2                148
# ...          ...              ...    ...             ...                ...
# 48882  -73.91079     Private room     40              20                  0
# 48884  -73.96238     Private room    190               7                  0
# 48887  -73.94220  Entire home/apt    170               1                  0
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 3      2019-07-05               4.64                               1
# 6      2017-10-05               0.40                               1
# 12     2019-06-24               1.34                               3
# 15     2019-06-29               1.20                               1
# ...           ...                ...                             ...
# 48882         NaN                NaN                               1
# 48884         NaN                NaN                               1
# 48887         NaN                NaN                               3
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
#
#        availability_365
# 0                   365
# 3                   194
# 6                     0
# 12                  314
# 15                   46
# ...                 ...
# 48882                31
# 48884               341
# 48887               365
# 48890                 9
# 48891                36
#
# [20104 rows x 16 columns]

# %% [markdown]
# # Room - wise filtering

# %%
def room_filter(room):
    return loc_df.loc[df['room_type'] == room.capitalize()]

# %%
room_df = room_filter(input("Enter required room type: "))
room_df
# Out:
# Enter required room type: Private room
#              id                                             name    host_id  \
# 0          2539               Clean & quiet apt home by the park       2787
# 6          5121                                  BlissArtsSpace!       7356
# 12         5803   Lovely Room 1, Garden, Best Area, Legal rental       9744
# 21         8024                   CBG CtyBGd HelpsHaiti rm#1:1-4      22486
# 22         8025                         CBG Helps Haiti Room#2.5      22486
# ...         ...                                              ...        ...
# 48881  36481615                 Peaceful space in Greenpoint, BK  274298453
# 48882  36482231                        Bushwick _ Myrtle-Wyckoff   66058896
# 48884  36482783      Brooklyn Oasis in the heart of Williamsburg  274307600
# 48890  36484665  Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057    Affordable room in Bushwick/East Williamsburg    6570630
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          John            Brooklyn          Kensington  40.64749  -73.97237
# 6         Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 12       Laurie            Brooklyn         South Slope  40.66829  -73.98779
# 21        Lisel            Brooklyn          Park Slope  40.68069  -73.97706
# 22        Lisel            Brooklyn          Park Slope  40.67989  -73.97798
# ...         ...                 ...                 ...       ...        ...
# 48881    Adrien            Brooklyn          Greenpoint  40.72585  -73.94001
# 48882     Luisa            Brooklyn            Bushwick  40.69652  -73.91079
# 48884  Jonathan            Brooklyn        Williamsburg  40.71790  -73.96238
# 48890   Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853  -73.94995
# 48891   Marisol            Brooklyn            Bushwick  40.70184  -73.93317
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Private room    149               1                  9  2018-10-19
# 6      Private room     60              45                 49  2017-10-05
# 12     Private room     89               4                167  2019-06-24
# 21     Private room    130               2                130  2019-07-01
# 22     Private room     80               1                 39  2019-01-01
# ...             ...    ...             ...                ...         ...
# 48881  Private room     54               6                  0         NaN
# 48882  Private room     40              20                  0         NaN
# 48884  Private room    190               7                  0         NaN
# 48890  Private room     70               2                  0         NaN
# 48891  Private room     40               4                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.21                               6               365
# 6                   0.40                               1                 0
# 12                  1.34                               3               314
# 21                  1.09                               6               347
# 22                  0.37                               6               364
# ...                  ...                             ...               ...
# 48881                NaN                               1                15
# 48882                NaN                               1                31
# 48884                NaN                               1               341
# 48890                NaN                               2                 9
# 48891                NaN                               2                36
#
# [10132 rows x 16 columns]

# %% [markdown]
# # Price - wise filtering

# %%
def price(max_price, min_price):
    price_df = room_df.loc[(df['price'] <= max_price) & (df['price'] >= min_price)]
    return price_df.sort_values(by = 'price')

# %%
price_df = price(int(input("Enter maximum price: ")), int(input("Enter minimum price: ")))
price_df
# Out:
# Enter maximum price: 400
# Enter minimum price: 0
#              id                                               name    host_id  \
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# ...         ...                                                ...        ...
# 23030  18649351             BEST LOCATION, ONLY 5 MIN TO MANHATAN.   69124870
# 27870  21827363  BUSINESS OR SINGLE TRAVELLER BEDROOM, BEST IN ...   69124870
# 11198   8671786                              Room in pre-war space    6639602
# 23534  19053614        ONLY 5 MIN TO MANHATAN, BRAND NEW APARTMENT   69124870
# 45621  34864369                    dumbo gem with garden sleeps 3.  121080979
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# 25796       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68258
# 25795       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68279
# 25794       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68173
# 23161      Kimberly            Brooklyn  Bedford-Stuyvesant  40.69023
# 25753        Lauren            Brooklyn          Greenpoint  40.72462
# ...             ...                 ...                 ...       ...
# 23030  Ana Y Victor            Brooklyn        Williamsburg  40.71039
# 27870  Ana Y Victor            Brooklyn        Williamsburg  40.70801
# 11198         Allie            Brooklyn        Williamsburg  40.71151
# 23534  Ana Y Victor            Brooklyn        Williamsburg  40.71118
# 45621         Jason            Brooklyn               DUMBO  40.70378
#
#        longitude     room_type  price  minimum_nights  number_of_reviews  \
# 25796  -73.91284  Private room      0               1                 95
# 25795  -73.91170  Private room      0               1                 95
# 25794  -73.91342  Private room      0               1                 93
# 23161  -73.95428  Private room      0               4                  1
# 25753  -73.94072  Private room      0               2                 12
# ...          ...           ...    ...             ...                ...
# 23030  -73.96139  Private room    400               1                 44
# 27870  -73.95902  Private room    400               1                 23
# 11198  -73.96665  Private room    400               3                  0
# 23534  -73.96080  Private room    400               1                 49
# 45621  -73.99278  Private room    400               3                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 25796  2019-06-23               4.35                               6
# 25795  2019-06-21               4.37                               6
# 25794  2019-06-15               4.28                               6
# 23161  2018-01-06               0.05                               4
# 25753  2017-10-27               0.53                               2
# ...           ...                ...                             ...
# 23030  2019-05-08               2.19                               4
# 27870  2019-06-18               1.36                               4
# 11198         NaN                NaN                               1
# 23534  2019-06-18               2.48                               4
# 45621         NaN                NaN                               1
#
#        availability_365
# 25796               222
# 25795               232
# 25794               176
# 23161                28
# 25753                 0
# ...                 ...
# 23030                77
# 27870                77
# 11198                 0
# 23534                77
# 45621               136
#
# [10081 rows x 16 columns]

# %% [markdown]
# # Sorting existing dataset by number of reviews
# (Highest to Lowest)

# %%
def review_filter():
    sort_by_review_df = price_df.sort_values(by = 'number_of_reviews', ascending = False)
    return sort_by_review_df

# %%
review_filter()
# Out:
#              id                                               name    host_id  \
# 471      166172                    LG Private Room/Family Friendly     792159
# 137       31994                 Room with En Suite Bathroom & Deck     137814
# 534      195233  Hospitality on Propsect Pk-12 yrs Hosting Lega...     949221
# 8352    6422875                   Brooklyn Creative Snooze Factory   33510832
# 2439    1217318                    Williamsburg Penthouse Hideaway    6642777
# ...         ...                                                ...        ...
# 28742  22213572   2 bedroom available in the heart of Williamsburg   13795760
# 6934    4967258                private room avail in lovely BK apt   25082897
# 36113  28699654     Home For Medical Professionals - "The Kinetic"   26377263
# 41697  32420992  Large Brooklyn Room! A/C & Rooftop Manhattan V...   15336905
# 45621  34864369                    dumbo gem with garden sleeps 3.  121080979
#
#         host_name neighbourhood_group              neighbourhood  latitude  \
# 471         Wanda            Brooklyn                   Bushwick  40.70283
# 137      Waldemar            Brooklyn               Clinton Hill  40.68730
# 534        Dennis            Brooklyn  Prospect-Lefferts Gardens  40.65513
# 8352     Benjamin            Brooklyn         Bedford-Stuyvesant  40.69271
# 2439       Martin            Brooklyn               Williamsburg  40.71024
# ...           ...                 ...                        ...       ...
# 28742  Eliza Love            Brooklyn               Williamsburg  40.71420
# 6934          Fen            Brooklyn                   Bushwick  40.70516
# 36113        Stat            Brooklyn              East Flatbush  40.65429
# 41697    Michelle            Brooklyn         Bedford-Stuyvesant  40.68837
# 45621       Jason            Brooklyn                      DUMBO  40.70378
#
#        longitude     room_type  price  minimum_nights  number_of_reviews  \
# 471    -73.92131  Private room     60               3                480
# 137    -73.96340  Private room     76               2                426
# 534    -73.95641  Private room     43               1                401
# 8352   -73.94353  Private room     70               1                397
# 2439   -73.95170  Private room    105               1                374
# ...          ...           ...    ...             ...                ...
# 28742  -73.96099  Private room     85               1                  0
# 6934   -73.91609  Private room     40               1                  0
# 36113  -73.93601  Private room     57              30                  0
# 41697  -73.93560  Private room     57               2                  0
# 45621  -73.99278  Private room    400               3                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 471    2019-07-07               6.70                               1
# 137    2019-06-24               3.89                               3
# 534    2019-07-04               6.62                               2
# 8352   2019-06-28               7.97                               2
# 2439   2019-06-23               5.06                               2
# ...           ...                ...                             ...
# 28742         NaN                NaN                               2
# 6934          NaN                NaN                               1
# 36113         NaN                NaN                              43
# 41697         NaN                NaN                               1
# 45621         NaN                NaN                               1
#
#        availability_365
# 471                   0
# 137                 275
# 534                  43
# 8352                 35
# 2439                 69
# ...                 ...
# 28742                 0
# 6934                  0
# 36113               306
# 41697                61
# 45621               136
#
# [10081 rows x 16 columns]
